# %%
import re
import os
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
def parse_log_file(filepath):
    sections = {"prompt": "", "response": "", "scores": []}
    current_section = None
    ground_truth_line = None

    with open(filepath, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if line == "=== Generated Prompt ===":
                current_section = "prompt"
                continue
            elif line == "=== GPT Response ===":
                current_section = "response"
                continue
            elif line == "=== Collecting and Comparing Assertions ===":
                current_section = "scores"
                continue

            if current_section == "prompt":
                sections["prompt"] += line + "\n"
            elif current_section == "response":
                sections["response"] += line + "\n"
            elif current_section == "scores":
                if line.startswith("=== Ground Oracle Truth:"):
                    ground_truth_line = (
                        line.replace("=== Ground Oracle Truth:", "")
                        .strip()
                        .replace(" ===", "")
                    )
                elif re.match(r"^\d+\.\d+\s*-\s*", line):
                    match = re.match(r"^(\d+\.\d+)", line)
                    if match:
                        sections["scores"].append(float(match.group(1)))

    sections["ground_truth"] = ground_truth_line
    return sections

# %%
def calc_log_data(log_folder):
    log_data = []
    for filename in os.listdir(log_folder):
        if filename.endswith(".log"):
            filepath = os.path.join(log_folder, filename)
            parsed_data = parse_log_file(filepath)
            if parsed_data["scores"]:
                log_data.append(
                    {
                        "file": filename,
                        "ground_truth": parsed_data.get("ground_truth"),
                        "top_score": parsed_data["scores"][0]
                        if parsed_data["scores"]
                        else None,
                        "avg_score": np.mean(parsed_data["scores"])
                        if parsed_data["scores"]
                        else None,
                        "full_log": parsed_data,
                    }
                )
    return log_data

# %%
def save_logs_as_json(log_data, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    for entry in log_data:
        output_path = os.path.join(output_folder, f"{entry['file']}.json")
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(entry["full_log"], f, indent=4)

# %%
def plot_log_data(log_data, output_path):
    all_scores = [entry["top_score"] for entry in log_data]
    overall_avg = np.mean(all_scores)
    overall_std = np.std(all_scores)

    plt.figure(figsize=(10, 6))
    plt.hist(all_scores, bins=20, color="skyblue", edgecolor="black")
    plt.title(
        f"Distribution of Similarity Scores\n(Overall Avg: {overall_avg:.3f}, Std: {overall_std:.3f})"
    )
    plt.xlabel("Similarity Score")
    plt.ylabel("Number of Log Files")
    plt.savefig(output_path)
    plt.close()
    return overall_avg, overall_std

# %%
def print_stats(log_data):
    print(f"Processed {len(log_data)} log files")
    for entry in log_data:
        print(f"File: {entry['file']}")
        print(f"  Ground Oracle Truth: {entry['ground_truth']}")
        print(f"  Average Similarity Score: {entry['avg_score']:.3f}")
        print(f"  Top Score: {entry['top_score']:.3f}")
        print("------")

# %%
models = ["gpt-35-turbo", "gpt-4o-mini"]
temps = [0.0, 0.2, 0.7]
log_folders = [f"./assets/logs/{model}/{temp}" for temp in temps for model in models]

print(log_folders)

for log_folder in log_folders:
    if not os.path.exists(log_folder):
        print(f"Log folder does not exist: {log_folder}")
        continue

    log_data = calc_log_data(log_folder)

    output_json_folder = (
        f"./assets/processed_logs/{log_folder.replace('./assets/logs/', '')}"
    )
    save_logs_as_json(log_data, output_json_folder)

    plot_output_path = f"../results/{log_folder.replace('./logs/', '').replace('/', '_')}_distribution.png"
    overall_avg, overall_std = plot_log_data(log_data, plot_output_path)

    print(f"Processed logs from {log_folder}")
    print(f"  Overall Average Similarity Score: {overall_avg:.3f}")
    print(f"  Overall Standard Deviation: {overall_std:.3f}")
    print_stats(log_data)
# Out:
# ['./assets/logs/gpt-35-turbo/0.0', './assets/logs/gpt-4o-mini/0.0', './assets/logs/gpt-35-turbo/0.2', './assets/logs/gpt-4o-mini/0.2', './assets/logs/gpt-35-turbo/0.7', './assets/logs/gpt-4o-mini/0.7']
# Processed logs from ./assets/logs/gpt-35-turbo/0.0
#   Overall Average Similarity Score: 0.833
#   Overall Standard Deviation: 0.195
# Processed 441 log files
# File: 20250607_173544_testGetContext.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.461
#   Top Score: 1.000
# ------
# File: 20250607_180107_testFriendsOfFriends.log
#   Ground Oracle Truth: assertEquals(1,qResult.size());
#   Average Similarity Score: 0.538
#   Top Score: 0.984
# ------
# File: 20250607_180545_testGetProperty.log
#   Ground Oracle Truth: assertEquals("STR",create(env).getProperty("STR"));
#   Average Similarity Score: 0.553
#   Top Score: 0.844
# ------
# File: 20250607_174857_testGetPolledObjects.log
#   Ground Oracle Truth: assertEquals(this.polledObjects,this.poller.getPolledObjects());
#   Average Similarity Score: 0.601
#   Top Score: 0.763
# ------
# File: 20250607_180902_verifyFilterAllowsNonSentryLoggers.log
#   Ground Oracle Truth: assertEquals(FilterReply.NEUTRAL,filter.decide(evt));
#   Average Similarity Score: 0.625
#   Top Score: 0.972
# ------
# File: 20250607_180833_testMergeDeploymentMetadataWithNoSpec.log
#   Ground Oracle Truth: assertNotNull(answer);
#   Average Similarity Score: 0.322
#   Top Score: 0.468
# ------
# File: 20250607_173601_testEdgeCasesWithFakeZ.log
#   Ground Oracle Truth: assertEquals(a.estimateSize(),computeSize);
#   Average Similarity Score: 0.580
#   Top Score: 0.800
# ------
# File: 20250607_180022_testAsciiBytes.log
#   Ground Oracle Truth: Assert.assertArrayEquals(newbyte[]{102,111,111},Charsetfunctions.asciiBytes("STR"));
#   Average Similarity Score: 0.828
#   Top Score: 0.906
# ------
# File: 20250607_180126_testESBuffer.log
#   Ground Oracle Truth: assertArrayEquals(frame1,NIOUtils.toArray(f1.getData()));
#   Average Similarity Score: 0.553
#   Top Score: 0.809
# ------
# File: 20250607_173158_nestedLinkSet.log
#   Ground Oracle Truth: assertNotNull(nest1);
#   Average Similarity Score: 0.293
#   Top Score: 0.378
# ------
# File: 20250607_180904_testIsEmpty.log
#   Ground Oracle Truth: assertFalse(StringUtils.isEmpty("STR"));
#   Average Similarity Score: 0.879
#   Top Score: 0.960
# ------
# File: 20250607_180540_testSelectNoTargetSkip.log
#   Ground Oracle Truth: Assert.assertFalse(result.hasNext());
#   Average Similarity Score: 0.618
#   Top Score: 1.000
# ------
# File: 20250607_180135_testRegisterMultiInterestUserProcessor.log
#   Ground Oracle Truth: Assert.assertEquals(((SimpleServerMultiInterestUserProcessor)multiInterestUserProcessor).multiInterest().size(),userProcessors.size());
#   Average Similarity Score: 0.505
#   Top Score: 0.730
# ------
# File: 20250607_180205_testBaseRoutePrioritizerAddNullRoute.log
#   Ground Oracle Truth: Assert.assertEquals(0,routePrioritizer.getPrioritizedRoutes().size());
#   Average Similarity Score: 0.859
#   Top Score: 0.984
# ------
# File: 20250607_173607_testGetAddressIndex_fromAgent.log
#   Ground Oracle Truth: assertEquals(5,agentAddress(5).getAddressIndex());
#   Average Similarity Score: 0.846
#   Top Score: 0.869
# ------
# File: 20250607_180456_testMissingKeyReturnsErrorResponse.log
#   Ground Oracle Truth: assertNotNull(handshakeResponse);
#   Average Similarity Score: 0.497
#   Top Score: 1.000
# ------
# File: 20250607_180613_testThreadSpawnerException_reportException.log
#   Ground Oracle Truth: assertTrue(exceptionFile.exists());
#   Average Similarity Score: 0.467
#   Top Score: 1.000
# ------
# File: 20250607_180521_testGetKeyTypes.log
#   Ground Oracle Truth: Assert.assertEquals(simpleKeyIndexDefinition.getTypes(),newOType[]{OType.INTEGER,OType.STRING});
#   Average Similarity Score: 0.579
#   Top Score: 0.787
# ------
# File: 20250607_173446_testEmpty.log
#   Ground Oracle Truth: assertNull(result);
#   Average Similarity Score: 0.702
#   Top Score: 0.923
# ------
# File: 20250607_173503_testReadIntraChromaPredMode.log
#   Ground Oracle Truth: Assert.assertEquals(0,newCABAC(1).readIntraChromaPredMode(m,0,null,null,false,false));
#   Average Similarity Score: 0.753
#   Top Score: 0.893
# ------
# File: 20250607_174849_testAnchorFilterFalse.log
#   Ground Oracle Truth: Assert.assertEquals(url.toExternalForm(),filterResult);
#   Average Similarity Score: 0.553
#   Top Score: 0.684
# ------
# File: 20250607_174910_testLinkCollectionOther.log
#   Ground Oracle Truth: assertTrue(manager2.isSame(manager));
#   Average Similarity Score: 0.080
#   Top Score: 0.080
# ------
# File: 20250607_180941_nopūzdamās.log
#   Ground Oracle Truth: assertTrue(nopūzdamās.isRecognized());
#   Average Similarity Score: 0.604
#   Top Score: 1.000
# ------
# File: 20250607_181137_removes_underscores_from_keys.log
#   Ground Oracle Truth: assertEquals("STR",config.getString("STR"));
#   Average Similarity Score: 0.700
#   Top Score: 0.870
# ------
# File: 20250607_180841_ticket37.log
#   Ground Oracle Truth: assertTrue(panest.isRecognized());
#   Average Similarity Score: 0.435
#   Top Score: 0.733
# ------
# File: 20250607_173432_testDoubleWithingQuotes.log
#   Ground Oracle Truth: assertFalse(res.isEmpty());
#   Average Similarity Score: 0.508
#   Top Score: 1.000
# ------
# File: 20250607_180919_testChangesValuesNestedTrackingSet.log
#   Ground Oracle Truth: assertEquals(1,timeLine.getMultiValueChangeEvents().size());
#   Average Similarity Score: 0.073
#   Top Score: 0.073
# ------
# File: 20250607_180442_testDisableOpenJ9SCC_lowercase.log
#   Ground Oracle Truth: assertEquals(expectedDockerfileLines,dockerfileLines);
#   Average Similarity Score: 0.787
#   Top Score: 0.897
# ------
# File: 20250607_180354_testGetAll.log
#   Ground Oracle Truth: Assert.assertEquals(1,conns.size());
#   Average Similarity Score: 0.633
#   Top Score: 0.964
# ------
# File: 20250607_181202_testWindowsLineConventions.log
#   Ground Oracle Truth: assertEquals(EXPECTED,markup.markdown("STR"));
#   Average Similarity Score: 0.423
#   Top Score: 0.438
# ------
# File: 20250607_180630_testDefaultAndMinMaxUnsafeProperty.log
#   Ground Oracle Truth: assertEquals(idProperty.getName(),PROP_ID);
#   Average Similarity Score: 0.659
#   Top Score: 0.791
# ------
# File: 20250607_180954_testMastered.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.565
#   Top Score: 0.764
# ------
# File: 20250607_181020_testEqualsDifferentClass.log
#   Ground Oracle Truth: assertFalse(multiKey.equals("STR"));
#   Average Similarity Score: 0.625
#   Top Score: 0.870
# ------
# File: 20250607_174807_testGetMin.log
#   Ground Oracle Truth: assertEquals(expected,actual,0);
#   Average Similarity Score: 0.609
#   Top Score: 0.967
# ------
# File: 20250607_173552_loadKeyStoreFromResourcesWrongPassword.log
#   Ground Oracle Truth: assertNotNull(resourceAsStream);
#   Average Similarity Score: 0.609
#   Top Score: 1.000
# ------
# File: 20250607_174946_should_return_newer_tag.log
#   Ground Oracle Truth: Assert.assertEquals(latestTag,resultedTag);
#   Average Similarity Score: 0.540
#   Top Score: 1.000
# ------
# File: 20250607_180705_testFriendsWithName.log
#   Ground Oracle Truth: assertEquals(1,qResult.size());
#   Average Similarity Score: 0.663
#   Top Score: 0.967
# ------
# File: 20250607_180104_testDocFromJsonEmbedded.log
#   Ground Oracle Truth: Assert.assertEquals(result.size(),0);
#   Average Similarity Score: 0.646
#   Top Score: 0.761
# ------
# File: 20250607_180233_jaundzimušākais.log
#   Ground Oracle Truth: assertTrue(w.isRecognized());
#   Average Similarity Score: 0.378
#   Top Score: 1.000
# ------
# File: 20250607_173250_testWithSets.log
#   Ground Oracle Truth: Assert.assertEquals("STR",retrievedParent.getFriends().iterator().next().getName());
#   Average Similarity Score: 0.644
#   Top Score: 1.000
# ------
# File: 20250607_173550_testReadThorntailPort.log
#   Ground Oracle Truth: assertNotNull(props);
#   Average Similarity Score: 0.519
#   Top Score: 1.000
# ------
# File: 20250607_174932_testSameChars.log
#   Ground Oracle Truth: Assert.assertEquals("STR",CommUtil.repeatChar('b',10));
#   Average Similarity Score: 0.822
#   Top Score: 0.882
# ------
# File: 20250607_173407_testSetVerb.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.612
#   Top Score: 1.000
# ------
# File: 20250607_173409_testGetCorrectResponsesPattern.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.489
#   Top Score: 0.776
# ------
# File: 20250607_180535_testAnd.log
#   Ground Oracle Truth: Assert.assertTrue(resultinstanceofInteger);
#   Average Similarity Score: 0.521
#   Top Score: 0.526
# ------
# File: 20250607_180750_testGetInflater.log
#   Ground Oracle Truth: assertEquals(deflateExtension.getInflater().getRemaining(),newInflater(true).getRemaining());
#   Average Similarity Score: 0.733
#   Top Score: 0.771
# ------
# File: 20250607_180927_testToAndFrom.log
#   Ground Oracle Truth: Assert.assertArrayEquals(Y,resultHbd.getPlaneData(0));
#   Average Similarity Score: 0.753
#   Top Score: 1.000
# ------
# File: 20250607_180856_testLongOTP.log
#   Ground Oracle Truth: assertFalse(YubicoClient.isValidOTPFormat(otp));
#   Average Similarity Score: 0.643
#   Top Score: 0.946
# ------
# File: 20250607_181005_testGetAllWithPoolKey.log
#   Ground Oracle Truth: Assert.assertEquals(3,cm.getAll(poolKey).size());
#   Average Similarity Score: 0.874
#   Top Score: 0.976
# ------
# File: 20250607_180551_testGetAgents_withCount.log
#   Ground Oracle Truth: assertEquals(3,registry.agentCount());
#   Average Similarity Score: 0.822
#   Top Score: 1.000
# ------
# File: 20250607_173442_testBatchOperationsNoTx.log
#   Ground Oracle Truth: assertEquals(request.getOperations().size(),1);
#   Average Similarity Score: 0.641
#   Top Score: 0.957
# ------
# File: 20250607_180153_testStEqualsPoint.log
#   Ground Oracle Truth: Assert.assertEquals(next.field("STR"),true);
#   Average Similarity Score: 0.699
#   Top Score: 0.709
# ------
# File: 20250607_180428_testGetBranch.log
#   Ground Oracle Truth: assertEquals("STR",newTravis(env()).getBranch());
#   Average Similarity Score: 0.639
#   Top Score: 0.764
# ------
# File: 20250607_180515_testMatchesWithQuotes3.log
#   Ground Oracle Truth: assertEquals(results.size(),1);
#   Average Similarity Score: 0.644
#   Top Score: 0.933
# ------
# File: 20250607_174836_allows_overriding_mask.log
#   Ground Oracle Truth: assertEquals(expectedEnv,envFilter.filter(env));
#   Average Similarity Score: 0.634
#   Top Score: 0.969
# ------
# File: 20250607_173152_testGetTypes.log
#   Ground Oracle Truth: Assert.assertEquals(result.length,1);
#   Average Similarity Score: 0.634
#   Top Score: 0.931
# ------
# File: 20250607_181147_testGetObjectType.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.512
#   Top Score: 1.000
# ------
# File: 20250607_173216_testReconnectionByUserSetting.log
#   Ground Oracle Truth: Assert.assertEquals(0,clientDisConnectProcessor.getDisConnectTimes());
#   Average Similarity Score: 0.538
#   Top Score: 0.660
# ------
# File: 20250607_180623_testMatchesAgainstText.log
#   Ground Oracle Truth: assertTrue(Wildcards.matches("STR","STR"));
#   Average Similarity Score: 0.782
#   Top Score: 0.857
# ------
# File: 20250607_173255_testSetCustom.log
#   Ground Oracle Truth: Assert.assertNotNull(result);
#   Average Similarity Score: 0.549
#   Top Score: 0.750
# ------
# File: 20250607_180851_pēdiņas.log
#   Ground Oracle Truth: assertEquals(1,sentences.size());
#   Average Similarity Score: 0.766
#   Top Score: 1.000
# ------
# File: 20250607_181037_testCreateConnectionUsingSystemProperties.log
#   Ground Oracle Truth: assertSame(result,this.mockJmxMbeanConnection);
#   Average Similarity Score: 0.468
#   Top Score: 0.696
# ------
# File: 20250607_180500_testJoinListNull.log
#   Ground Oracle Truth: Assert.assertEquals("STR",Seq.join(null,"STR"));
#   Average Similarity Score: 0.526
#   Top Score: 0.949
# ------
# File: 20250607_180335_testMultipleProfilesParsing.log
#   Ground Oracle Truth: assertTrue(props.size()>0);
#   Average Similarity Score: 0.042
#   Top Score: 0.042
# ------
# File: 20250607_173155_testSerializeWALChanges.log
#   Ground Oracle Truth: Assert.assertEquals(stringSerializer.getObjectSizeInByteBuffer(buffer,walChanges,serializationOffset),stringSerializer.getObjectSize(OBJECT));
#   Average Similarity Score: 0.464
#   Top Score: 0.528
# ------
# File: 20250607_173347_testIndexingComplexUpdateTxPoint.log
#   Ground Oracle Truth: Assert.assertEquals(3,index.getSize());
#   Average Similarity Score: 0.486
#   Top Score: 0.968
# ------
# File: 20250607_173501_equal_even_with_different_history.log
#   Ground Oracle Truth: assertEquals(a,b);
#   Average Similarity Score: 0.619
#   Top Score: 1.000
# ------
# File: 20250607_180453_testDontFixMangledQueryString.log
#   Ground Oracle Truth: assertEquals("STR",expectedResult,normalizedUrl);
#   Average Similarity Score: 0.513
#   Top Score: 0.933
# ------
# File: 20250607_173628_testGetProvidedExtensionAsClient.log
#   Ground Oracle Truth: assertEquals("STR",defaultExtension.getProvidedExtensionAsClient());
#   Average Similarity Score: 0.803
#   Top Score: 1.000
# ------
# File: 20250607_181142_testSetState.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.428
#   Top Score: 1.000
# ------
# File: 20250607_173421_testGetSetBatchPollProcessor.log
#   Ground Oracle Truth: assertNotNull(this.poller.getBatchPollProcessor());
#   Average Similarity Score: 0.818
#   Top Score: 0.860
# ------
# File: 20250607_180813_testFieldSize.log
#   Ground Oracle Truth: Assert.assertEquals(floatSerializer.getObjectSize(null),FIELD_SIZE);
#   Average Similarity Score: 0.727
#   Top Score: 0.759
# ------
# File: 20250607_174750_testArrayRange2.log
#   Ground Oracle Truth: Assert.assertTrue(result.hasNext());
#   Average Similarity Score: 0.644
#   Top Score: 1.000
# ------
# File: 20250607_180159_testCreateValueWrongParameterArrayParams.log
#   Ground Oracle Truth: Assert.assertNull(propertyIndex.createValue("STR"));
#   Average Similarity Score: 0.655
#   Top Score: 0.762
# ------
# File: 20250607_173332_testCreateValueByValueTwoParametersArrayParams.log
#   Ground Oracle Truth: Assert.assertTrue(resultinstanceofCollection);
#   Average Similarity Score: 0.760
#   Top Score: 1.000
# ------
# File: 20250607_174959_testGetDuration.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.554
#   Top Score: 1.000
# ------
# File: 20250607_173241_testSetAttachments.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.287
#   Top Score: 0.566
# ------
# File: 20250607_180616_duplicates_bamboo_prefixed_env_vars_with_prefixless_copy.log
#   Ground Oracle Truth: assertEquals("STR",convertedEnv.get("STR"));
#   Average Similarity Score: 0.646
#   Top Score: 1.000
# ------
# File: 20250607_180145_actual_cost_is_actual_steps.log
#   Ground Oracle Truth: assertEquals(2,s.getActualCost());
#   Average Similarity Score: 0.612
#   Top Score: 1.000
# ------
# File: 20250607_173439_testDropClusterIfExists.log
#   Ground Oracle Truth: Assert.assertTrue(db.getClusterIdByName(cluster)>0);
#   Average Similarity Score: 0.579
#   Top Score: 0.710
# ------
# File: 20250607_173518_testCreateConnectionFailedToGetUrl.log
#   Ground Oracle Truth: assertNull(result);
#   Average Similarity Score: 0.234
#   Top Score: 1.000
# ------
# File: 20250607_173611_testSimpleLimit.log
#   Ground Oracle Truth: assertEquals(1,qResult.size());
#   Average Similarity Score: 0.513
#   Top Score: 0.967
# ------
# File: 20250607_173229_compile_WhenIgnoreWarnings.log
#   Ground Oracle Truth: Assert.assertEquals(0,res.size());
#   Average Similarity Score: 0.682
#   Top Score: 0.962
# ------
# File: 20250607_180450_createFramesText.log
#   Ground Oracle Truth: assertEquals(1,createdFrame.size());
#   Average Similarity Score: 0.613
#   Top Score: 1.000
# ------
# File: 20250607_173546_testGetUsageType.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.526
#   Top Score: 1.000
# ------
# File: 20250607_180017_testUnixLineConventions.log
#   Ground Oracle Truth: assertEquals(EXPECTED,m.markdown("STR"));
#   Average Similarity Score: 0.556
#   Top Score: 0.681
# ------
# File: 20250607_181105_find.log
#   Ground Oracle Truth: assertTrue(matcher.find());
#   Average Similarity Score: 0.781
#   Top Score: 1.000
# ------
# File: 20250607_180304_testTruncateVertexClassSubclassesWithIndex.log
#   Ground Oracle Truth: Assert.assertEquals(toList(result).size(),2);
#   Average Similarity Score: 0.570
#   Top Score: 0.818
# ------
# File: 20250607_174908_testTriangle2.log
#   Ground Oracle Truth: assertEquals(1,result.size());
#   Average Similarity Score: 0.615
#   Top Score: 0.966
# ------
# File: 20250607_180700_testDoubleWithFrac1.log
#   Ground Oracle Truth: assertEquals("STR",result);
#   Average Similarity Score: 0.481
#   Top Score: 0.885
# ------
# File: 20250607_180416_testSerialization.log
#   Ground Oracle Truth: Assert.assertEquals(from.getClusterId(),to.getClusterId());
#   Average Similarity Score: 0.576
#   Top Score: 1.000
# ------
# File: 20250607_180158_testCreateEdgeClass.log
#   Ground Oracle Truth: Assert.assertNotNull(clazz);
#   Average Similarity Score: 0.505
#   Top Score: 1.000
# ------
# File: 20250607_181041_testReplaceObjectNameParameters.log
#   Ground Oracle Truth: assertEquals("STR",result);
#   Average Similarity Score: 0.620
#   Top Score: 1.000
# ------
# File: 20250607_180131_izskanjas.log
#   Ground Oracle Truth: assertTrue(austrumlatvija.isRecognized());
#   Average Similarity Score: 0.542
#   Top Score: 0.876
# ------
# File: 20250607_173335_testSaveAndLoad_BinaryFieldsSimpleRecordMapping.log
#   Ground Oracle Truth: Assert.assertNotNull(savedHunt);
#   Average Similarity Score: 0.552
#   Top Score: 1.000
# ------
# File: 20250607_173448_testLiveQueryPushRequest.log
#   Ground Oracle Truth: assertEquals(pushRequestRead.getMonitorId(),10);
#   Average Similarity Score: 0.640
#   Top Score: 0.936
# ------
# File: 20250607_174945_testDecodeCustomResponse.log
#   Ground Oracle Truth: assertTrue(XML.equals(resp));
#   Average Similarity Score: 0.557
#   Top Score: 0.654
# ------
# File: 20250607_174809_testVerb.log
#   Ground Oracle Truth: assertNotNull(verb);
#   Average Similarity Score: 0.500
#   Top Score: 1.000
# ------
# File: 20250607_180459_testWithinDomain.log
#   Ground Oracle Truth: Assert.assertEquals("STR",filterResult);
#   Average Similarity Score: 0.622
#   Top Score: 1.000
# ------
# File: 20250607_173231_tuStum.log
#   Ground Oracle Truth: assertTrue(stum.isRecognized());
#   Average Similarity Score: 0.467
#   Top Score: 1.000
# ------
# File: 20250607_180432_testSetFieldValue.log
#   Ground Oracle Truth: assertNull(setFieldTest.injectField);
#   Average Similarity Score: 0.423
#   Top Score: 0.582
# ------
# File: 20250607_173615_shouldIndexVeryLongDescriptionWithSingleField.log
#   Ground Oracle Truth: Assert.assertEquals(1,count);
#   Average Similarity Score: 0.350
#   Top Score: 1.000
# ------
# File: 20250607_180028_testReadIntraMode.log
#   Ground Oracle Truth: Assert.assertEquals(3,newModeInfo().readKfIntraMode(miCol,miRow,blSz,decoder,c));
#   Average Similarity Score: 0.446
#   Top Score: 0.950
# ------
# File: 20250607_180426_testSubDirectoryCreation.log
#   Ground Oracle Truth: assertTrue(newJsonWriter(job,f).getCoverallsFile().getParentFile().isDirectory());
#   Average Similarity Score: 0.398
#   Top Score: 0.540
# ------
# File: 20250607_173620_testRemoveLinkedClass.log
#   Ground Oracle Truth: assertNotNull(prop.getLinkedClass());
#   Average Similarity Score: 0.455
#   Top Score: 0.747
# ------
# File: 20250607_180549_testGetAtMostOneVoidMethodWithoutArgs.log
#   Ground Oracle Truth: assertEquals("STR",method.getName());
#   Average Similarity Score: 0.566
#   Top Score: 0.805
# ------
# File: 20250607_180939_vairāki.log
#   Ground Oracle Truth: assertTrue(vairāki.isRecognized());
#   Average Similarity Score: 0.815
#   Top Score: 1.000
# ------
# File: 20250607_174828_noFilters.log
#   Ground Oracle Truth: assertEquals(list,result);
#   Average Similarity Score: 0.339
#   Top Score: 0.778
# ------
# File: 20250607_180507_testPaging.log
#   Ground Oracle Truth: assertEquals("STR",sql.toString());
#   Average Similarity Score: 0.613
#   Top Score: 0.791
# ------
# File: 20250607_174800_testSystemSettings_takesEffect_before_defaultvalue.log
#   Ground Oracle Truth: Assert.assertTrue(client1.isConnectionMonitorSwitchOn());
#   Average Similarity Score: 0.784
#   Top Score: 1.000
# ------
# File: 20250607_173406_validStringMessageWithoutTZWithLocaleAndValidationTest.log
#   Ground Oracle Truth: Assert.assertNotNull(parser.parse(sample1,true,Locale.FRANCE));
#   Average Similarity Score: 0.371
#   Top Score: 0.679
# ------
# File: 20250607_180815_testWithOResult.log
#   Ground Oracle Truth: assertEquals(newLinkedHashSet(Arrays.asList("STR","STR")),result);
#   Average Similarity Score: 0.415
#   Top Score: 0.510
# ------
# File: 20250607_181112_testFetchFromSingleRid.log
#   Ground Oracle Truth: Assert.assertTrue(result.hasNext());
#   Average Similarity Score: 0.616
#   Top Score: 1.000
# ------
# File: 20250607_173248_testDefaultValueFromJson.log
#   Ground Oracle Truth: assertNotNull(saved.field("STR"));
#   Average Similarity Score: 0.629
#   Top Score: 1.000
# ------
# File: 20250607_173321_testGetAttributes.log
#   Ground Oracle Truth: assertEquals(2,atts.size());
#   Average Similarity Score: 0.487
#   Top Score: 0.963
# ------
# File: 20250607_173314_testParseEpochMillis.log
#   Ground Oracle Truth: assertEquals(time,parsed.getTime());
#   Average Similarity Score: 0.645
#   Top Score: 1.000
# ------
# File: 20250607_181122_testOptimizePartialOptimizationMethod.log
#   Ground Oracle Truth: Assert.assertEquals(filter.getRootCondition().toString(),"STR");
#   Average Similarity Score: 0.465
#   Top Score: 0.554
# ------
# File: 20250607_181059_markdown.log
#   Ground Oracle Truth: assertEquals("STR",Label.markdown("STR").value);
#   Average Similarity Score: 0.641
#   Top Score: 0.735
# ------
# File: 20250607_180255_testKeepFieldTypeSerialization.log
#   Ground Oracle Truth: assertEquals(doc.fieldType("STR"),OType.INTEGER);
#   Average Similarity Score: 0.649
#   Top Score: 0.731
# ------
# File: 20250607_180752_ts.log
#   Ground Oracle Truth: assertTrue(nopūsts.isRecognized());
#   Average Similarity Score: 0.699
#   Top Score: 1.000
# ------
# File: 20250607_180212_testJoinListEmpty.log
#   Ground Oracle Truth: Assert.assertEquals("STR",Seq.join(Collections.EMPTY_LIST,"STR"));
#   Average Similarity Score: 0.492
#   Top Score: 0.729
# ------
# File: 20250607_174921_testCommaList.log
#   Ground Oracle Truth: Assert.assertEquals("STR",Seq.join(Arrays.asList("STR","STR","STR"),"STR"));
#   Average Similarity Score: 0.678
#   Top Score: 0.835
# ------
# File: 20250607_180156_testToLowerCase.log
#   Ground Oracle Truth: assertEquals(1,getResult().size());
#   Average Similarity Score: 0.494
#   Top Score: 0.667
# ------
# File: 20250607_173323_testGetSetLog.log
#   Ground Oracle Truth: assertNotNull(this.processor.getLog());
#   Average Similarity Score: 0.704
#   Top Score: 0.930
# ------
# File: 20250607_174927_has_yaml_representation.log
#   Ground Oracle Truth: assertEquals(expected,config.toYaml("STR"));
#   Average Similarity Score: 0.586
#   Top Score: 0.889
# ------
# File: 20250607_180011_getTestCase_null.log
#   Ground Oracle Truth: assertNull(testSuite.getTestCase(null));
#   Average Similarity Score: 0.759
#   Top Score: 1.000
# ------
# File: 20250607_175958_testSleep.log
#   Ground Oracle Truth: Assert.assertTrue(System.currentTimeMillis()-begin>=500);
#   Average Similarity Score: 0.220
#   Top Score: 0.290
# ------
# File: 20250607_180059_testGlobalPropertyCreate.log
#   Ground Oracle Truth: assertEquals(prop.getName(),"STR");
#   Average Similarity Score: 0.559
#   Top Score: 0.824
# ------
# File: 20250607_180639_testSimpleEmbeddedDoc.log
#   Ground Oracle Truth: assertEquals(document.fields(),extr.fields());
#   Average Similarity Score: 0.417
#   Top Score: 0.496
# ------
# File: 20250607_173704_reset.log
#   Ground Oracle Truth: assertTrue(matcher.find());
#   Average Similarity Score: 1.000
#   Top Score: 1.000
# ------
# File: 20250607_180603_testExtends.log
#   Ground Oracle Truth: assertEquals("STR",true,frameinstanceofDataFrame);
#   Average Similarity Score: 0.504
#   Top Score: 0.547
# ------
# File: 20250607_180811_testLink.log
#   Ground Oracle Truth: assertEquals(2,manager.getNewRecords().size());
#   Average Similarity Score: 0.771
#   Top Score: 1.000
# ------
# File: 20250607_174914_testRidSelect.log
#   Ground Oracle Truth: Assert.assertTrue(listener.latch.await(10,TimeUnit.SECONDS));
#   Average Similarity Score: 0.375
#   Top Score: 0.495
# ------
# File: 20250607_180933_testCustomDepthZero.log
#   Ground Oracle Truth: Assert.assertEquals(null,filterResult);
#   Average Similarity Score: 0.648
#   Top Score: 0.784
# ------
# File: 20250607_173252_testLazyExecutionPlanning.log
#   Ground Oracle Truth: Assert.assertEquals("STR",item.getProperty("STR"));
#   Average Similarity Score: 0.500
#   Top Score: 0.705
# ------
# File: 20250607_173543_testSetExtensions.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.466
#   Top Score: 1.000
# ------
# File: 20250607_173359_testToString.log
#   Ground Oracle Truth: assertEquals("STR",protocol0.getProvidedProtocol());
#   Average Similarity Score: 0.819
#   Top Score: 1.000
# ------
# File: 20250607_173427_testNonExistentYamlToPropertiesParsing.log
#   Ground Oracle Truth: assertNotNull(props);
#   Average Similarity Score: 0.552
#   Top Score: 0.919
# ------
# File: 20250607_180635_testLiveEvents.log
#   Ground Oracle Truth: assertEquals(mock.countCreate,1);
#   Average Similarity Score: 0.489
#   Top Score: 0.620
# ------
# File: 20250607_180344_reziduāļi.log
#   Ground Oracle Truth: assertTrue(m.isRecognized());
#   Average Similarity Score: 0.554
#   Top Score: 1.000
# ------
# File: 20250607_174925_testDefaultValues.log
#   Ground Oracle Truth: assertEquals("STR",Opcode.BINARY,binary.getOpcode());
#   Average Similarity Score: 0.521
#   Top Score: 0.939
# ------
# File: 20250607_180557_testGetSetJmxMbeanConnectorFactory.log
#   Ground Oracle Truth: assertTrue(this.factory.getJmxMBeanConnectionFactory()instanceofDefaultJmxMBeanConnectionFactory);
#   Average Similarity Score: 0.572
#   Top Score: 0.840
# ------
# File: 20250607_174741_test1Returns1.log
#   Ground Oracle Truth: assertEquals("STR",result);
#   Average Similarity Score: 0.954
#   Top Score: 0.981
# ------
# File: 20250607_173523_testPrepareObjectQueryWithParameterReplacement.log
#   Ground Oracle Truth: assertSame(this.testTarget002,result.getTarget());
#   Average Similarity Score: 0.534
#   Top Score: 0.920
# ------
# File: 20250607_180242_testSleepTimeUnit.log
#   Ground Oracle Truth: assertTrue(format("STR",duration),duration>0);
#   Average Similarity Score: 0.550
#   Top Score: 0.709
# ------
# File: 20250607_180114_testAddTurtle.log
#   Ground Oracle Truth: assertEquals(1,panel.getTurtleCount());
#   Average Similarity Score: 0.731
#   Top Score: 1.000
# ------
# File: 20250607_180440_testCopyFile.log
#   Ground Oracle Truth: assertTrue(targetFile.exists());
#   Average Similarity Score: 0.585
#   Top Score: 1.000
# ------
# File: 20250607_180643_getPropertyValueTest.log
#   Ground Oracle Truth: assertEquals("STR",Configs.getSystemPropertyWithMavenPropertyAsFallback(properties,KEY_1));
#   Average Similarity Score: 0.867
#   Top Score: 0.934
# ------
# File: 20250607_173603_testToNextMarkerPartialVar1.log
#   Ground Oracle Truth: Assert.assertEquals(ByteBuffer.wrap(bytes,0,8),buf1);
#   Average Similarity Score: 0.488
#   Top Score: 0.528
# ------
# File: 20250607_181043_testImmutableQueryInfo.log
#   Ground Oracle Truth: assertSame(target,objectQueryInfo.getTarget());
#   Average Similarity Score: 0.605
#   Top Score: 0.915
# ------
# File: 20250607_180246_removeOne.log
#   Ground Oracle Truth: assertTrue(handler.hasInitContainer(builder,"STR"));
#   Average Similarity Score: 0.885
#   Top Score: 0.923
# ------
# File: 20250607_173435_testProcessChangeEventRemoveKeyWithConversion.log
#   Ground Oracle Truth: Assert.assertEquals(keysToAdd,addedKeys);
#   Average Similarity Score: 0.565
#   Top Score: 0.706
# ------
# File: 20250607_180830_targetType_whenMember.log
#   Ground Oracle Truth: assertEquals(asList(list.get(1),list.get(3)),result);
#   Average Similarity Score: 0.539
#   Top Score: 0.674
# ------
# File: 20250607_181153_testDecodeFrame.log
#   Ground Oracle Truth: assertArrayEquals(message,frame.getPayloadData().array());
#   Average Similarity Score: 0.659
#   Top Score: 0.826
# ------
# File: 20250607_173538_testIndexedEdgeArrows.log
#   Ground Oracle Truth: Assert.assertTrue(result.hasNext());
#   Average Similarity Score: 0.573
#   Top Score: 1.000
# ------
# File: 20250607_174815_testExists.log
#   Ground Oracle Truth: assertEquals(false,ACollectionHelper.exists(Arrays.<String>asList(),len1));
#   Average Similarity Score: 0.753
#   Top Score: 0.815
# ------
# File: 20250607_180807_testOptional3.log
#   Ground Oracle Truth: assertEquals(1,qResult.size());
#   Average Similarity Score: 0.636
#   Top Score: 0.967
# ------
# File: 20250607_180349_turn.log
#   Ground Oracle Truth: assertEquals("STR",Records.turn(Records.rec("STR","STR"),"STR"));
#   Average Similarity Score: 0.471
#   Top Score: 0.684
# ------
# File: 20250607_180309_checkIniParameter2.log
#   Ground Oracle Truth: Assert.assertEquals("STR",newRouterNanoHTTPD.UriResource("STR",100,null,"STR").initParameter(String.class));
#   Average Similarity Score: 0.556
#   Top Score: 0.596
# ------
# File: 20250607_180652_validMessageValidationAllExtenstionsTest.log
#   Ground Oracle Truth: Assert.assertNotNull(parser.parse(sample1,true));
#   Average Similarity Score: 0.792
#   Top Score: 1.000
# ------
# File: 20250607_173527_testIssue23.log
#   Ground Oracle Truth: Assert.assertTrue(true);
#   Average Similarity Score: 0.327
#   Top Score: 0.444
# ------
# File: 20250607_181125_testQuotedEmptyString.log
#   Ground Oracle Truth: assertFalse(res.isEmpty());
#   Average Similarity Score: 0.608
#   Top Score: 0.863
# ------
# File: 20250607_180418_testNewParser.log
#   Ground Oracle Truth: Assert.assertEquals(v1.getClassName(),OrientVertexType.CLASS_NAME);
#   Average Similarity Score: 0.376
#   Top Score: 0.494
# ------
# File: 20250607_180101_testAlterRemoveLinkedType.log
#   Ground Oracle Truth: Assert.assertNotNull(result);
#   Average Similarity Score: 0.357
#   Top Score: 1.000
# ------
# File: 20250607_180414_testDocumentToIndexCollectionValueEmptyTwoNullValuesSupport.log
#   Ground Oracle Truth: Assert.assertEquals(result,Arrays.asList(newOCompositeKey(null,12)));
#   Average Similarity Score: 0.459
#   Top Score: 0.531
# ------
# File: 20250607_181130_javascript.log
#   Ground Oracle Truth: assertTrue(promise.getAnswer()instanceofString);
#   Average Similarity Score: 0.561
#   Top Score: 0.633
# ------
# File: 20250607_180056_testEqualNull.log
#   Ground Oracle Truth: assertFalse(compositeKey.equals(null));
#   Average Similarity Score: 0.721
#   Top Score: 0.907
# ------
# File: 20250607_173633_validByteArrayMessageWithoutValidationTest.log
#   Ground Oracle Truth: Assert.assertNotNull(parser.parse(sample1Array));
#   Average Similarity Score: 0.492
#   Top Score: 0.682
# ------
# File: 20250607_174949_validLoggerReturned_whenOpenThenCloseThenOpenWithSameParameters.log
#   Ground Oracle Truth: assertEquals(null,logger.sender);
#   Average Similarity Score: 0.615
#   Top Score: 0.693
# ------
# File: 20250607_180322_testGet.log
#   Ground Oracle Truth: assertFalse(performanceStats.isEmpty());
#   Average Similarity Score: 0.616
#   Top Score: 0.814
# ------
# File: 20250607_173203_testMoveSingleRecordToAnotherClass.log
#   Ground Oracle Truth: Assert.assertEquals(doc.getIdentity().getClusterId(),customer.getDefaultClusterId());
#   Average Similarity Score: 0.407
#   Top Score: 0.407
# ------
# File: 20250607_173234_testMergeIfAbsent.log
#   Ground Oracle Truth: assertEquals(expected,origMap);
#   Average Similarity Score: 0.647
#   Top Score: 0.647
# ------
# File: 20250607_180041_testMergeMaps.log
#   Ground Oracle Truth: assertEquals(expectedA,MapUtil.mergeMaps(mapA,mapB));
#   Average Similarity Score: 0.776
#   Top Score: 1.000
# ------
# File: 20250607_181015_testAddressHashCode.log
#   Ground Oracle Truth: assertNotEquals(0,macAddress.hashCode());
#   Average Similarity Score: 0.510
#   Top Score: 0.556
# ------
# File: 20250607_180408_testPersistentRIDAfterCommit.log
#   Ground Oracle Truth: Assert.assertTrue(((ORID)v.getId()).isPersistent());
#   Average Similarity Score: 0.502
#   Top Score: 0.633
# ------
# File: 20250607_181119_testManualIndex.log
#   Ground Oracle Truth: Assert.assertEquals(manual.getSize(),4);
#   Average Similarity Score: 0.558
#   Top Score: 0.806
# ------
# File: 20250607_180710_findPrefix.log
#   Ground Oracle Truth: assertTrue(matcher.find());
#   Average Similarity Score: 0.934
#   Top Score: 1.000
# ------
# File: 20250607_180542_vajadzības_minēšana.log
#   Ground Oracle Truth: assertTrue(vārds.isRecognized());
#   Average Similarity Score: 0.620
#   Top Score: 1.000
# ------
# File: 20250607_173205_testSetupWithIncompleteJob.log
#   Ground Oracle Truth: assertEquals("STR",mojo.serviceName);
#   Average Similarity Score: 0.494
#   Top Score: 0.718
# ------
# File: 20250607_173305_testAllForbidden.log
#   Ground Oracle Truth: Assert.assertEquals("STR",filterResult);
#   Average Similarity Score: 0.469
#   Top Score: 1.000
# ------
# File: 20250607_173211_sum_of_cell_distances_is_distance_to_goal.log
#   Ground Oracle Truth: assertEquals(4,p.getDistanceToGoal());
#   Average Similarity Score: 0.966
#   Top Score: 0.987
# ------
# File: 20250607_180958_testGetBuildUrl.log
#   Ground Oracle Truth: assertEquals("STR",newAppveyor(env()).getBuildUrl());
#   Average Similarity Score: 0.658
#   Top Score: 0.733
# ------
# File: 20250607_180327_testToString_whenCoordinator.log
#   Ground Oracle Truth: assertEquals("STR",coordinatorAddress().toString());
#   Average Similarity Score: 0.819
#   Top Score: 0.841
# ------
# File: 20250607_180401_testAddWconnithPoolKey_multiPoolKey.log
#   Ground Oracle Truth: Assert.assertEquals(1,cm.count(poolKey));
#   Average Similarity Score: 0.890
#   Top Score: 1.000
# ------
# File: 20250607_180657_testFromJavaUtil.log
#   Ground Oracle Truth: assertEquals(l,l2);
#   Average Similarity Score: 0.619
#   Top Score: 0.791
# ------
# File: 20250607_181009_commonPath.log
#   Ground Oracle Truth: Assert.assertEquals("STR",node.getPath());
#   Average Similarity Score: 1.000
#   Top Score: 1.000
# ------
# File: 20250607_180003_testStorageUpdate.log
#   Ground Oracle Truth: assertEquals(database.get(ODatabase.ATTRIBUTES.LOCALELANGUAGE),Locale.GERMANY.getLanguage());
#   Average Similarity Score: 0.422
#   Top Score: 0.535
# ------
# File: 20250607_174916_testTxLinked.log
#   Ground Oracle Truth: assertEquals(3,db.countClass("STR"));
#   Average Similarity Score: 0.627
#   Top Score: 0.676
# ------
# File: 20250607_180740_puzzle_can_swap_blank.log
#   Ground Oracle Truth: assertEquals(4,c.getBlankIndex());
#   Average Similarity Score: 0.707
#   Top Score: 1.000
# ------
# File: 20250607_180508_testDuplicateNullsOnCreate.log
#   Ground Oracle Truth: Assert.assertEquals(person2,index.get("STR"));
#   Average Similarity Score: 0.607
#   Top Score: 0.861
# ------
# File: 20250607_181057_testBitValue.log
#   Ground Oracle Truth: Assert.assertEquals("STR",CommUtil.hexdump(CommUtil.bitValue(b)));
#   Average Similarity Score: 0.360
#   Top Score: 0.463
# ------
# File: 20250607_174842_testCustomDepth.log
#   Ground Oracle Truth: Assert.assertEquals(url.toExternalForm(),filterResult);
#   Average Similarity Score: 0.544
#   Top Score: 0.733
# ------
# File: 20250607_173558_testWithinHostOnly.log
#   Ground Oracle Truth: Assert.assertEquals("STR",filterResult);
#   Average Similarity Score: 0.624
#   Top Score: 1.000
# ------
# File: 20250607_181102_testReadingXiphV2.log
#   Ground Oracle Truth: Assert.assertEquals(12,be.headerSize);
#   Average Similarity Score: 0.649
#   Top Score: 0.949
# ------
# File: 20250607_180252_serializePosition.log
#   Ground Oracle Truth: assertEquals(OVarIntSerializer.readAsLong(bytes),16238l);
#   Average Similarity Score: 0.217
#   Top Score: 0.883
# ------
# File: 20250607_181132_bind_Integer.log
#   Ground Oracle Truth: assertTrue(bind0(testObject,"STR","STR"));
#   Average Similarity Score: 0.417
#   Top Score: 0.444
# ------
# File: 20250607_173351_testIndexReload.log
#   Ground Oracle Truth: Assert.assertEquals(result,compositeIndex);
#   Average Similarity Score: 0.544
#   Top Score: 0.609
# ------
# File: 20250607_173604_testMissingSourceFileFromDirectory.log
#   Ground Oracle Truth: assertNull(sourceLoader.load("STR"));
#   Average Similarity Score: 0.722
#   Top Score: 0.795
# ------
# File: 20250607_180139_testAdd.log
#   Ground Oracle Truth: Assert.assertEquals(1,cm.count(poolKey));
#   Average Similarity Score: 0.802
#   Top Score: 0.971
# ------
# File: 20250607_180823_external.log
#   Ground Oracle Truth: assertEquals(attrs(attr("STR",label.external())),attrs(label.external()));
#   Average Similarity Score: 0.378
#   Top Score: 0.491
# ------
# File: 20250607_181013_testGetFileFromConfigDirectory.log
#   Ground Oracle Truth: assertTrue(configFile.exists());
#   Average Similarity Score: 0.689
#   Top Score: 1.000
# ------
# File: 20250607_173258_testConversion.log
#   Ground Oracle Truth: assertEquals(newInteger(23),durationSeconds("STR"));
#   Average Similarity Score: 0.669
#   Top Score: 0.707
# ------
# File: 20250607_174743_testProjection.log
#   Ground Oracle Truth: assertEquals(qResult.size(),1);
#   Average Similarity Score: 0.587
#   Top Score: 0.933
# ------
# File: 20250607_180723_testFilterNoMD.log
#   Ground Oracle Truth: Assert.assertEquals(url.toExternalForm(),filterResult);
#   Average Similarity Score: 0.569
#   Top Score: 1.000
# ------
# File: 20250607_173452_testExecutionBeginTransaction.log
#   Ground Oracle Truth: assertFalse(database.getTransaction().isActive());
#   Average Similarity Score: 0.024
#   Top Score: 0.024
# ------
# File: 20250607_174802_testNull.log
#   Ground Oracle Truth: assertEquals("STR",m.markdown(null));
#   Average Similarity Score: 0.558
#   Top Score: 0.765
# ------
# File: 20250607_174939_testSerialize.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.425
#   Top Score: 0.592
# ------
# File: 20250607_180839_testDeleteFile.log
#   Ground Oracle Truth: assertTrue(tempSrcFile.exists());
#   Average Similarity Score: 0.777
#   Top Score: 1.000
# ------
# File: 20250607_173705_bind_Double.log
#   Ground Oracle Truth: assertTrue(bind0(testObject,"STR","STR"));
#   Average Similarity Score: 0.483
#   Top Score: 0.496
# ------
# File: 20250607_181139_testSetOther.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.486
#   Top Score: 1.000
# ------
# File: 20250607_173256_testMixCompositeQuery.log
#   Ground Oracle Truth: Assert.assertEquals(1,docs.size());
#   Average Similarity Score: 0.541
#   Top Score: 1.000
# ------
# File: 20250607_180956_testGetMbox.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.506
#   Top Score: 1.000
# ------
# File: 20250607_180129_testSetInstructor.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.539
#   Top Score: 1.000
# ------
# File: 20250607_173649_uriToString.log
#   Ground Oracle Truth: Assert.assertEquals("STR",newUriResource("STR",100,GeneralHandler.class).toString());
#   Average Similarity Score: 0.517
#   Top Score: 0.592
# ------
# File: 20250607_180112_testReplayedOTP.log
#   Ground Oracle Truth: assertNotNull(response);
#   Average Similarity Score: 0.543
#   Top Score: 0.643
# ------
# File: 20250607_173344_testStContainsPoint.log
#   Ground Oracle Truth: Assert.assertEquals(true,next.field("STR"));
#   Average Similarity Score: 0.586
#   Top Score: 0.753
# ------
# File: 20250607_180333_testSubClass_methodFoundInSuper.log
#   Ground Oracle Truth: assertEquals(1,methodList.size());
#   Average Similarity Score: 0.524
#   Top Score: 1.000
# ------
# File: 20250607_180404_testAddIndexNotificationThree.log
#   Ground Oracle Truth: Assert.assertFalse(doc.isDirty());
#   Average Similarity Score: 0.727
#   Top Score: 1.000
# ------
# File: 20250607_180731_checkEURRUS.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrEURRUS.convert(V_300D));
#   Average Similarity Score: 0.654
#   Top Score: 0.709
# ------
# File: 20250607_173214_testLoad_justKey.log
#   Ground Oracle Truth: assertTrue(simulatorProperties.get("STR").isEmpty());
#   Average Similarity Score: 0.672
#   Top Score: 0.679
# ------
# File: 20250607_180631_shouldCheckSubclasses.log
#   Ground Oracle Truth: Assert.assertEquals(0,result.stream().count());
#   Average Similarity Score: 0.546
#   Top Score: 0.848
# ------
# File: 20250607_180805_testEmptyCollection.log
#   Ground Oracle Truth: assertEquals(0,getResult().size());
#   Average Similarity Score: 0.775
#   Top Score: 0.889
# ------
# File: 20250607_180531_testNegativeDouble.log
#   Ground Oracle Truth: assertTrue(resultinstanceofDouble);
#   Average Similarity Score: 0.396
#   Top Score: 0.971
# ------
# File: 20250607_180547_testSetId.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.556
#   Top Score: 1.000
# ------
# File: 20250607_180101_testRemoveTwo.log
#   Ground Oracle Truth: Assert.assertFalse(doc.isDirty());
#   Average Similarity Score: 0.644
#   Top Score: 1.000
# ------
# File: 20250607_173310_testFilterDocumentWithMetadata.log
#   Ground Oracle Truth: Assert.assertEquals("STR","STR",fields.get("STR"));
#   Average Similarity Score: 0.505
#   Top Score: 0.925
# ------
# File: 20250607_174919_testFormatMap.log
#   Ground Oracle Truth: Assert.assertArrayEquals(newString[]{"STR","STR","STR"},actuals);
#   Average Similarity Score: 0.485
#   Top Score: 0.621
# ------
# File: 20250607_174912_testRemoveNotificationOne.log
#   Ground Oracle Truth: Assert.assertFalse(doc.isDirty());
#   Average Similarity Score: 0.616
#   Top Score: 1.000
# ------
# File: 20250607_180435_parseTags.log
#   Ground Oracle Truth: assertEquals(toMap("STR","STR","STR","STR","STR","STR"),result);
#   Average Similarity Score: 0.339
#   Top Score: 0.457
# ------
# File: 20250607_173353_testES.log
#   Ground Oracle Truth: assertArrayEquals(frame1,NIOUtils.toArray(f1.getData()));
#   Average Similarity Score: 0.508
#   Top Score: 0.809
# ------
# File: 20250607_180759_testNormalCustomSerializer.log
#   Ground Oracle Truth: Assert.assertEquals(RequestBody.DEFAULT_SERVER_RETURN_STR+"STR",ret);
#   Average Similarity Score: 0.333
#   Top Score: 0.494
# ------
# File: 20250607_173541_testGetCategory.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.632
#   Top Score: 1.000
# ------
# File: 20250607_180116_testDisableOpenJ9SCC_mixedcase.log
#   Ground Oracle Truth: assertEquals(expectedDockerfileLines,dockerfileLines);
#   Average Similarity Score: 0.719
#   Top Score: 0.883
# ------
# File: 20250607_181107_checkPER1000.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrPER1000.convert(12.346));
#   Average Similarity Score: 0.621
#   Top Score: 0.684
# ------
# File: 20250607_173642_testSetStatements.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.596
#   Top Score: 1.000
# ------
# File: 20250607_180405_testFloatWithinQuotesAndCommaAsDecimalSeparator.log
#   Ground Oracle Truth: assertFalse(res.isEmpty());
#   Average Similarity Score: 0.478
#   Top Score: 0.545
# ------
# File: 20250607_180227_testGroupByEquals.log
#   Ground Oracle Truth: assertEquals(3,grouped.size());
#   Average Similarity Score: 0.627
#   Top Score: 0.967
# ------
# File: 20250607_174839_testFilterMetadata.log
#   Ground Oracle Truth: Assert.assertArrayEquals("STR",newString[]{"STR","STR","STR"},newTreeSet<>(fields.keySet()).toArray());
#   Average Similarity Score: 0.470
#   Top Score: 0.470
# ------
# File: 20250607_180422_testMatchesAgainstWildcards.log
#   Ground Oracle Truth: assertTrue(Wildcards.matches("STR","STR"));
#   Average Similarity Score: 0.778
#   Top Score: 0.857
# ------
# File: 20250607_181023_testSimple.log
#   Ground Oracle Truth: assertNotNull(bytesContainer.bytes);
#   Average Similarity Score: 0.750
#   Top Score: 0.906
# ------
# File: 20250607_181003_testGetDeflater.log
#   Ground Oracle Truth: assertEquals(deflateExtension.getDeflater().finished(),newDeflater(Deflater.DEFAULT_COMPRESSION,true).finished());
#   Average Similarity Score: 0.582
#   Top Score: 0.623
# ------
# File: 20250607_180148_testBlob.log
#   Ground Oracle Truth: Assert.assertTrue(db.getClusterIdByName(clusterName)>0);
#   Average Similarity Score: 0.527
#   Top Score: 0.604
# ------
# File: 20250607_180301_exportImportExcludeClusters.log
#   Ground Oracle Truth: Assert.assertTrue(dbImp.getMetadata().getSchema().existsClass("STR"));
#   Average Similarity Score: 0.789
#   Top Score: 1.000
# ------
# File: 20250607_173245_testTerminated.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.449
#   Top Score: 0.764
# ------
# File: 20250607_180040_testGetPidStringOrNull.log
#   Ground Oracle Truth: assertNotNull(pid);
#   Average Similarity Score: 0.609
#   Top Score: 1.000
# ------
# File: 20250607_180421_testQueryEmbeddedMap.log
#   Ground Oracle Truth: assertNotNull(item.getProperty("STR"));
#   Average Similarity Score: 0.579
#   Top Score: 0.775
# ------
# File: 20250607_173412_checkUAHRUS.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrUAHRUS.convert(V_300D));
#   Average Similarity Score: 0.659
#   Top Score: 0.696
# ------
# File: 20250607_173525_testArray1.log
#   Ground Oracle Truth: assertEquals("STR",result);
#   Average Similarity Score: 0.561
#   Top Score: 0.836
# ------
# File: 20250607_180913_testQueryUpdateCreatedInTxTransaction.log
#   Ground Oracle Truth: assertTrue(result.hasNext());
#   Average Similarity Score: 0.036
#   Top Score: 0.036
# ------
# File: 20250607_180658_testNil.log
#   Ground Oracle Truth: assertEquals(0,AList.nil().size());
#   Average Similarity Score: 0.726
#   Top Score: 0.896
# ------
# File: 20250607_180119_testXiph.log
#   Ground Oracle Truth: assertArrayEquals(expecteds,MkvBlock.muxXiphLacing(_in));
#   Average Similarity Score: 0.655
#   Top Score: 1.000
# ------
# File: 20250607_180910_testConstructor_withTestClassInstance.log
#   Ground Oracle Truth: assertEquals(test,testContainer.getTestInstance());
#   Average Similarity Score: 0.671
#   Top Score: 0.804
# ------
# File: 20250607_180716_testYuv420pToRgbH2H.log
#   Ground Oracle Truth: Assert.assertArrayEquals(rgbH,out.getPlaneData(0));
#   Average Similarity Score: 0.676
#   Top Score: 0.844
# ------
# File: 20250607_180216_testSetAgent.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.653
#   Top Score: 1.000
# ------
# File: 20250607_173702_testGetName.log
#   Ground Oracle Truth: assertEquals("STR",newCircle(env()).getName());
#   Average Similarity Score: 0.544
#   Top Score: 0.753
# ------
# File: 20250607_173404_testAddressNormalizedSeparator.log
#   Ground Oracle Truth: assertEquals(NORMALIZED_ADDRESS,macAddress.toString());
#   Average Similarity Score: 0.779
#   Top Score: 0.779
# ------
# File: 20250607_180718_defaultRocketMqProducer.log
#   Ground Oracle Truth: Assert.assertTrue(this.context.containsBean("STR"));
#   Average Similarity Score: 0.291
#   Top Score: 0.367
# ------
# File: 20250607_173636_ignores_log_level_case.log
#   Ground Oracle Truth: assertEquals(Logger.Level.DEBUG,logger.level);
#   Average Similarity Score: 0.429
#   Top Score: 0.571
# ------
# File: 20250607_180703_testNodesWithoutEdges.log
#   Ground Oracle Truth: assertTrue(eqSet(graph.edges(),edge("STR","STR")));
#   Average Similarity Score: 0.534
#   Top Score: 0.621
# ------
# File: 20250607_173401_testGetDrafts.log
#   Ground Oracle Truth: assertEquals(1,server.getDraft().size());
#   Average Similarity Score: 0.656
#   Top Score: 0.825
# ------
# File: 20250607_180906_bind_short_whitespace.log
#   Ground Oracle Truth: assertTrue(bind0(testObject,"STR","STR"));
#   Average Similarity Score: 0.423
#   Top Score: 0.484
# ------
# File: 20250607_174942_fixedLengthContentIsEncodedProperly.log
#   Ground Oracle Truth: assertEquals("STR",EntityUtils.toString(response.getEntity()));
#   Average Similarity Score: 0.412
#   Top Score: 0.903
# ------
# File: 20250607_180744_testSpaces.log
#   Ground Oracle Truth: assertEquals("STR",m.markdown("STR"));
#   Average Similarity Score: 0.640
#   Top Score: 0.878
# ------
# File: 20250607_173645_testInvokeStatic2.log
#   Ground Oracle Truth: assertEquals(42,parseBuf);
#   Average Similarity Score: 0.760
#   Top Score: 0.939
# ------
# File: 20250607_180320_testConstructor_withMessageFormat_singleArgument.log
#   Ground Oracle Truth: assertEquals("STR",exception.getMessage());
#   Average Similarity Score: 0.673
#   Top Score: 1.000
# ------
# File: 20250607_180223_testSetDisplay.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.545
#   Top Score: 1.000
# ------
# File: 20250607_173150_testProcessChangeEventAddKeyWithConversion.log
#   Ground Oracle Truth: Assert.assertEquals(keysToAdd,addedKeys);
#   Average Similarity Score: 0.571
#   Top Score: 0.649
# ------
# File: 20250607_180411_testDocumentToIndexMapValueSuccessful.log
#   Ground Oracle Truth: Assert.assertEquals(collectionResult.size(),2);
#   Average Similarity Score: 0.480
#   Top Score: 0.949
# ------
# File: 20250607_173338_testPlain.log
#   Ground Oracle Truth: Assert.assertNotNull(db.getMetadata().getSequenceLibrary().getSequence(name));
#   Average Similarity Score: 0.742
#   Top Score: 1.000
# ------
# File: 20250607_180359_estimated_cost_is_zero_when_solved.log
#   Ground Oracle Truth: assertEquals(0,s.getEstimatedCost());
#   Average Similarity Score: 0.764
#   Top Score: 1.000
# ------
# ...
#   Average Similarity Score: 0.585
#   Top Score: 1.000
# ------
# File: 20250607_171500_testGetMore.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.476
#   Top Score: 0.840
# ------
# File: 20250607_165620_simple.log
#   Ground Oracle Truth: assertFalse(handler.hasInitContainer(builder,"STR"));
#   Average Similarity Score: 0.705
#   Top Score: 0.838
# ------
# File: 20250607_164943_testSetCustom.log
#   Ground Oracle Truth: Assert.assertNotNull(result);
#   Average Similarity Score: 0.390
#   Top Score: 0.643
# ------
# File: 20250607_165612_testSetTwoItems.log
#   Ground Oracle Truth: Assert.assertEquals(0,array.add(1));
#   Average Similarity Score: 0.739
#   Top Score: 1.000
# ------
# File: 20250607_171745_testDescription.log
#   Ground Oracle Truth: Assert.assertEquals("STR",value);
#   Average Similarity Score: 0.422
#   Top Score: 0.733
# ------
# File: 20250607_170219_izskanjas.log
#   Ground Oracle Truth: assertTrue(austrumlatvija.isRecognized());
#   Average Similarity Score: 0.646
#   Top Score: 1.000
# ------
# File: 20250607_171609_testTree.log
#   Ground Oracle Truth: assertFalse(graph.hasCycles());
#   Average Similarity Score: 0.525
#   Top Score: 0.881
# ------
# File: 20250607_165323_testGetCategory.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.475
#   Top Score: 0.840
# ------
# File: 20250607_165909_testDefaultValues.log
#   Ground Oracle Truth: assertEquals("STR",Opcode.BINARY,binary.getOpcode());
#   Average Similarity Score: 0.514
#   Top Score: 0.939
# ------
# File: 20250607_165953_fixedLengthContentIsEncodedProperly.log
#   Ground Oracle Truth: assertEquals("STR",EntityUtils.toString(response.getEntity()));
#   Average Similarity Score: 0.577
#   Top Score: 1.000
# ------
# File: 20250607_170638_testAddIndexNotificationThree.log
#   Ground Oracle Truth: Assert.assertFalse(doc.isDirty());
#   Average Similarity Score: 0.472
#   Top Score: 0.867
# ------
# File: 20250607_170056_testAsciiBytes.log
#   Ground Oracle Truth: Assert.assertArrayEquals(newbyte[]{102,111,111},Charsetfunctions.asciiBytes("STR"));
#   Average Similarity Score: 0.867
#   Top Score: 0.908
# ------
# File: 20250607_170952_testMatchesAgainstText.log
#   Ground Oracle Truth: assertTrue(Wildcards.matches("STR","STR"));
#   Average Similarity Score: 0.726
#   Top Score: 0.870
# ------
# File: 20250607_171124_defaultRocketMqProducer.log
#   Ground Oracle Truth: Assert.assertTrue(this.context.containsBean("STR"));
#   Average Similarity Score: 0.317
#   Top Score: 0.568
# ------
# File: 20250607_170736_testToInHg.log
#   Ground Oracle Truth: Assert.assertEquals(expected,actual);
#   Average Similarity Score: 0.462
#   Top Score: 0.646
# ------
# File: 20250607_170821_testGetKeyTypes.log
#   Ground Oracle Truth: Assert.assertEquals(simpleKeyIndexDefinition.getTypes(),newOType[]{OType.INTEGER,OType.STRING});
#   Average Similarity Score: 0.464
#   Top Score: 0.626
# ------
# File: 20250607_171112_testMBSkipFlag.log
#   Ground Oracle Truth: Assert.assertEquals(false,cabac.readMBSkipFlag(m,SliceType.P,false,false,0));
#   Average Similarity Score: 0.803
#   Top Score: 0.920
# ------
# File: 20250607_171010_testPropertiesParsing.log
#   Ground Oracle Truth: assertNotEquals(0,props.size());
#   Average Similarity Score: 0.514
#   Top Score: 0.915
# ------
# File: 20250607_170135_testOrderByDesc.log
#   Ground Oracle Truth: Assert.assertTrue(result.hasNext());
#   Average Similarity Score: 0.485
#   Top Score: 1.000
# ------
# File: 20250607_170238_testBlob.log
#   Ground Oracle Truth: Assert.assertTrue(db.getClusterIdByName(clusterName)>0);
#   Average Similarity Score: 0.378
#   Top Score: 0.537
# ------
# File: 20250607_165008_testAvcCToAnnexB.log
#   Ground Oracle Truth: Assert.assertArrayEquals(newbyte[]{0,0,0,1,0x67,'s','t','a','n',0,0,0,1,0x67,'t','h','e',0,0,0,1,0x68,'m','a','n',0,0,0,1,0x68,'c','o','o','l'},res);
#   Average Similarity Score: 0.298
#   Top Score: 0.458
# ------
# File: 20250607_171522_testGetAllWithPoolKey.log
#   Ground Oracle Truth: Assert.assertEquals(3,cm.getAll(poolKey).size());
#   Average Similarity Score: 0.438
#   Top Score: 0.720
# ------
# File: 20250607_171338_targetType_whenMember.log
#   Ground Oracle Truth: assertEquals(asList(list.get(1),list.get(3)),result);
#   Average Similarity Score: 0.343
#   Top Score: 0.680
# ------
# File: 20250607_170635_testAddWconnithPoolKey_multiPoolKey.log
#   Ground Oracle Truth: Assert.assertEquals(1,cm.count(poolKey));
#   Average Similarity Score: 0.598
#   Top Score: 0.892
# ------
# File: 20250607_165514_is_info_level_by_default.log
#   Ground Oracle Truth: assertEquals(Logger.Level.INFO,logger.level);
#   Average Similarity Score: 0.458
#   Top Score: 0.598
# ------
# File: 20250607_165626_testSystemSettings_takesEffect_before_defaultvalue.log
#   Ground Oracle Truth: Assert.assertTrue(client1.isConnectionMonitorSwitchOn());
#   Average Similarity Score: 0.572
#   Top Score: 0.980
# ------
# File: 20250607_171630_rakiens.log
#   Ground Oracle Truth: assertTrue(w.isRecognized());
#   Average Similarity Score: 0.455
#   Top Score: 1.000
# ------
# File: 20250607_170604_checkPER100.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrPER100.convert(V_1_01D));
#   Average Similarity Score: 0.614
#   Top Score: 0.661
# ------
# File: 20250607_165223_testLiveQueryPushRequest.log
#   Ground Oracle Truth: assertEquals(pushRequestRead.getMonitorId(),10);
#   Average Similarity Score: 0.516
#   Top Score: 0.698
# ------
# File: 20250607_171215_testSpaces.log
#   Ground Oracle Truth: assertEquals("STR",m.markdown("STR"));
#   Average Similarity Score: 0.488
#   Top Score: 0.579
# ------
# File: 20250607_165239_roundtrips.log
#   Ground Oracle Truth: assertEquals(yaml,config.toYaml("STR"));
#   Average Similarity Score: 0.532
#   Top Score: 0.659
# ------
# File: 20250607_165500_testHashCode.log
#   Ground Oracle Truth: assertEquals(defaultExtension0.hashCode(),defaultExtension1.hashCode());
#   Average Similarity Score: 0.730
#   Top Score: 0.986
# ------
# File: 20250607_165255_testCreateConnectionFailedToGetUrl.log
#   Ground Oracle Truth: assertNull(result);
#   Average Similarity Score: 0.302
#   Top Score: 0.818
# ------
# File: 20250607_170246_testStEqualsPoint.log
#   Ground Oracle Truth: Assert.assertEquals(next.field("STR"),true);
#   Average Similarity Score: 0.527
#   Top Score: 0.718
# ------
# File: 20250607_170810_testParamWithMatches.log
#   Ground Oracle Truth: assertEquals(results.size(),1);
#   Average Similarity Score: 0.553
#   Top Score: 0.933
# ------
# File: 20250607_171701_testQuotedEmptyString.log
#   Ground Oracle Truth: assertFalse(res.isEmpty());
#   Average Similarity Score: 0.400
#   Top Score: 1.000
# ------
# File: 20250607_165054_testES.log
#   Ground Oracle Truth: assertArrayEquals(frame1,NIOUtils.toArray(f1.getData()));
#   Average Similarity Score: 0.446
#   Top Score: 0.809
# ------
# File: 20250607_170514_testTruncateVertexClassSubclassesWithIndex.log
#   Ground Oracle Truth: Assert.assertEquals(toList(result).size(),2);
#   Average Similarity Score: 0.456
#   Top Score: 0.818
# ------
# File: 20250607_171602_testImmutableQueryInfo.log
#   Ground Oracle Truth: assertSame(target,objectQueryInfo.getTarget());
#   Average Similarity Score: 0.498
#   Top Score: 1.000
# ------
# File: 20250607_170937_testAttended.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.530
#   Top Score: 0.840
# ------
# File: 20250607_171158_checkEURRUSCustom.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrCustom.convert(V_300D));
#   Average Similarity Score: 0.640
#   Top Score: 0.724
# ------
# File: 20250607_171042_testCopyInstance.log
#   Ground Oracle Truth: assertEquals(protocol0,protoocl1);
#   Average Similarity Score: 0.590
#   Top Score: 0.879
# ------
# File: 20250607_170416_removeOne.log
#   Ground Oracle Truth: assertTrue(handler.hasInitContainer(builder,"STR"));
#   Average Similarity Score: 0.569
#   Top Score: 0.821
# ------
# File: 20250607_170903_testSetId.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.477
#   Top Score: 0.840
# ------
# File: 20250607_170640_testFloatWithinQuotesAndCommaAsDecimalSeparator.log
#   Ground Oracle Truth: assertFalse(res.isEmpty());
#   Average Similarity Score: 0.449
#   Top Score: 1.000
# ------
# File: 20250607_164913_tuStum.log
#   Ground Oracle Truth: assertTrue(stum.isRecognized());
#   Average Similarity Score: 0.543
#   Top Score: 1.000
# ------
# File: 20250607_171446_testNamespaceExtraction.log
#   Ground Oracle Truth: Assert.assertEquals(1,output.getEmitted().size());
#   Average Similarity Score: 0.462
#   Top Score: 0.690
# ------
# File: 20250607_171227_ts.log
#   Ground Oracle Truth: assertTrue(nopūsts.isRecognized());
#   Average Similarity Score: 0.555
#   Top Score: 1.000
# ------
# File: 20250607_171312_testFieldSize.log
#   Ground Oracle Truth: Assert.assertEquals(floatSerializer.getObjectSize(null),FIELD_SIZE);
#   Average Similarity Score: 0.689
#   Top Score: 0.759
# ------
# File: 20250607_165411_testMissingSourceFileFromDirectory.log
#   Ground Oracle Truth: assertNull(sourceLoader.load("STR"));
#   Average Similarity Score: 0.337
#   Top Score: 0.617
# ------
# File: 20250607_170507_testRefFlushedInTransaction.log
#   Ground Oracle Truth: assertEquals(1,result.stream().count());
#   Average Similarity Score: 0.415
#   Top Score: 1.000
# ------
# File: 20250607_170652_testDocumentToIndexCollectionValueEmptyTwoNullValuesSupport.log
#   Ground Oracle Truth: Assert.assertEquals(result,Arrays.asList(newOCompositeKey(null,12)));
#   Average Similarity Score: 0.371
#   Top Score: 0.515
# ------
# File: 20250607_171040_singleletters.log
#   Ground Oracle Truth: assertEquals(3,tokens.size());
#   Average Similarity Score: 0.596
#   Top Score: 0.966
# ------
# File: 20250607_170131_testCompareAndSetSingleItem.log
#   Ground Oracle Truth: Assert.assertEquals(0,array.add(1));
#   Average Similarity Score: 0.518
#   Top Score: 0.767
# ------
# File: 20250607_165419_shoudGetRightTimeFromString.log
#   Ground Oracle Truth: assertEquals(calendar.getTime(),d);
#   Average Similarity Score: 0.500
#   Top Score: 0.744
# ------
# File: 20250607_171413_bind_short_whitespace.log
#   Ground Oracle Truth: assertTrue(bind0(testObject,"STR","STR"));
#   Average Similarity Score: 0.346
#   Top Score: 0.565
# ------
# File: 20250607_165031_testSaveAndLoad_BinaryFieldsSimpleRecordMapping.log
#   Ground Oracle Truth: Assert.assertNotNull(savedHunt);
#   Average Similarity Score: 0.492
#   Top Score: 0.772
# ------
# File: 20250607_170423_findCharClass.log
#   Ground Oracle Truth: assertTrue(matcher.find());
#   Average Similarity Score: 0.682
#   Top Score: 0.981
# ------
# File: 20250607_170145_testRemoveTwo.log
#   Ground Oracle Truth: Assert.assertFalse(doc.isDirty());
#   Average Similarity Score: 0.469
#   Top Score: 0.885
# ------
# File: 20250607_165335_testReadThorntailPort.log
#   Ground Oracle Truth: assertNotNull(props);
#   Average Similarity Score: 0.356
#   Top Score: 0.833
# ------
# File: 20250607_171319_testWithOResult.log
#   Ground Oracle Truth: assertEquals(newLinkedHashSet(Arrays.asList("STR","STR")),result);
#   Average Similarity Score: 0.371
#   Top Score: 0.625
# ------
# File: 20250607_164851_testGeneratedConfigFiles.log
#   Ground Oracle Truth: assertTrue("STR",util.isGeneratedConfigFile(sourceFile,configDirectory,targetDir));
#   Average Similarity Score: 0.532
#   Top Score: 0.811
# ------
# File: 20250607_164838_sum_of_cell_distances_is_distance_to_goal.log
#   Ground Oracle Truth: assertEquals(4,p.getDistanceToGoal());
#   Average Similarity Score: 0.919
#   Top Score: 1.000
# ------
# File: 20250607_170717_testSetFieldValue.log
#   Ground Oracle Truth: assertNull(setFieldTest.injectField);
#   Average Similarity Score: 0.523
#   Top Score: 0.759
# ------
# File: 20250607_170406_testSleepTimeUnit.log
#   Ground Oracle Truth: assertTrue(format("STR",duration),duration>0);
#   Average Similarity Score: 0.415
#   Top Score: 0.586
# ------
# File: 20250607_171520_testGetDeflater.log
#   Ground Oracle Truth: assertEquals(deflateExtension.getDeflater().finished(),newDeflater(Deflater.DEFAULT_COMPRESSION,true).finished());
#   Average Similarity Score: 0.305
#   Top Score: 0.550
# ------
# File: 20250607_171452_nopūzdamās.log
#   Ground Oracle Truth: assertTrue(nopūzdamās.isRecognized());
#   Average Similarity Score: 0.550
#   Top Score: 0.902
# ------
# File: 20250607_170232_testIsEmptyNonZero.log
#   Ground Oracle Truth: assertFalse(StringUtils.isNonZero("STR"));
#   Average Similarity Score: 0.826
#   Top Score: 0.962
# ------
# File: 20250607_165415_testGetAddressIndex_fromAgent.log
#   Ground Oracle Truth: assertEquals(5,agentAddress(5).getAddressIndex());
#   Average Similarity Score: 0.610
#   Top Score: 0.869
# ------
# File: 20250607_170913_testRemoveWorker_viaSimulatorAddress.log
#   Ground Oracle Truth: assertEquals(5,registry.workerCount());
#   Average Similarity Score: 0.610
#   Top Score: 0.937
# ------
# File: 20250607_165437_testRemoveLinkedClass.log
#   Ground Oracle Truth: assertNotNull(prop.getLinkedClass());
#   Average Similarity Score: 0.509
#   Top Score: 0.747
# ------
# File: 20250607_170254_testCreateValueWrongParameterArrayParams.log
#   Ground Oracle Truth: Assert.assertNull(propertyIndex.createValue("STR"));
#   Average Similarity Score: 0.641
#   Top Score: 0.755
# ------
# File: 20250607_171544_testSkipOrdered.log
#   Ground Oracle Truth: assertEquals(19,results.size());
#   Average Similarity Score: 0.506
#   Top Score: 0.806
# ------
# File: 20250607_171406_verifyFilterAllowsNonSentryLoggers.log
#   Ground Oracle Truth: assertEquals(FilterReply.NEUTRAL,filter.decide(evt));
#   Average Similarity Score: 0.441
#   Top Score: 0.972
# ------
# File: 20250607_171232_testNormalCustomSerializer.log
#   Ground Oracle Truth: Assert.assertEquals(RequestBody.DEFAULT_SERVER_RETURN_STR+"STR",ret);
#   Average Similarity Score: 0.309
#   Top Score: 0.444
# ------
# File: 20250607_171721_testSetOther.log
#   Ground Oracle Truth: assertNotNull(actual);
#   Average Similarity Score: 0.452
#   Top Score: 0.840
# ------
# File: 20250607_165236_testTarget.log
#   Ground Oracle Truth: assertEquals(3,result.size());
#   Average Similarity Score: 0.528
#   Top Score: 1.000
# ------
# File: 20250607_171621_testBitValue.log
#   Ground Oracle Truth: Assert.assertEquals("STR",CommUtil.hexdump(CommUtil.bitValue(b)));
#   Average Similarity Score: 0.328
#   Top Score: 0.452
# ------
# File: 20250607_170707_testSubDirectoryCreation.log
#   Ground Oracle Truth: assertTrue(newJsonWriter(job,f).getCoverallsFile().getParentFile().isDirectory());
#   Average Similarity Score: 0.398
#   Top Score: 0.694
# ------
# File: 20250607_165537_testInvalidURI.log
#   Ground Oracle Truth: assertEquals("STR",expectedResult,normalizedUrl);
#   Average Similarity Score: 0.544
#   Top Score: 0.933
# ------
# File: 20250607_165124_checkUSDUKR.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrUSD.convert(V_300D));
#   Average Similarity Score: 0.663
#   Top Score: 0.750
# ------
# File: 20250607_165120_checkUAHRUS.log
#   Ground Oracle Truth: assertEquals("STR",moneyToStrUAHRUS.convert(V_300D));
#   Average Similarity Score: 0.649
#   Top Score: 0.724
# ------
# File: 20250607_170807_testMatches.log
#   Ground Oracle Truth: assertEquals(result.size(),1);
#   Average Similarity Score: 0.496
#   Top Score: 0.783
# ------
# File: 20250607_170841_testNegativeDouble.log
#   Ground Oracle Truth: assertTrue(resultinstanceofDouble);
#   Average Similarity Score: 0.492
#   Top Score: 1.000
# ------
# File: 20250607_165830_testCreateValidUrl.log
#   Ground Oracle Truth: assertEquals("STR",UrlUtils.create("STR").toURI().toASCIIString());
#   Average Similarity Score: 0.406
#   Top Score: 0.534
# ------
# File: 20250607_165846_testTriangle2.log
#   Ground Oracle Truth: assertEquals(1,result.size());
#   Average Similarity Score: 0.408
#   Top Score: 0.812
# ------
# File: 20250607_170016_testActivityDefinitionHashMapOfStringStringHashMapOfStringString.log
#   Ground Oracle Truth: assertNotNull(ad);
#   Average Similarity Score: 0.376
#   Top Score: 0.810
# ------
# File: 20250607_164920_testMultiThread.log
#   Ground Oracle Truth: Assert.assertTrue(time>=start);
#   Average Similarity Score: 0.375
#   Top Score: 0.720
# ------
# File: 20250607_170750_testMissingKeyReturnsErrorResponse.log
#   Ground Oracle Truth: assertNotNull(handshakeResponse);
#   Average Similarity Score: 0.600
#   Top Score: 0.889
# ------
# File: 20250607_170859_testGetProperty.log
#   Ground Oracle Truth: assertEquals("STR",create(env).getProperty("STR"));
#   Average Similarity Score: 0.433
#   Top Score: 0.832
# ------
